# %% [markdown]
# # PLACEMENT PREDICTOR

# %% [markdown]
# ## Steps:-
# 1. Preprocess + EDA + Feature Selection
# 2. Extract input and output columns
# 3. Scale the values
# 4. Train test split
# 5. Train the model
# 6. Evaluate the model/model selection
# 7. Deploy the model

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/harishwargad/Documents/Datasets/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
# Preprocess
df = df.iloc[:, 1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
# EDA
plt.scatter(df['cgpa'], df['iq'], c=df['placement'])
plt.xlabel('CGPA')
plt.ylabel('IQ')
# Out:
# Text(0, 0.5, 'IQ')

# %%
# Extract input and ouput columns
x = df.iloc[:, 0:2]
y = df.iloc[:, -1]

# %%
x.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 78   6.1   81.0
# 57   6.5  130.0
# 84   5.7  169.0
# 83   7.5  130.0
# 32   7.0  139.0
# ..   ...    ...
# 2    5.3  121.0
# 63   6.3  128.0
# 42   7.6   89.0
# 28   5.2   90.0
# 99   6.2  113.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 78    0
# 57    1
# 84    0
# 83    1
# 32    1
#      ..
# 2     0
# 63    1
# 42    1
# 28    0
# 99    1
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 7    5.0   63.0
# 38   6.5  160.0
# 15   5.1  176.0
# 89   4.9  151.0
# 37   8.1  149.0
# 29   7.0  112.0
# 23   4.7   87.0
# 49   5.4  135.0
# 24   4.7  121.0
# 56   6.1   65.0

# %%
y_test
# Out:
# 7     0
# 38    1
# 15    0
# 89    0
# 37    1
# 29    1
# 23    0
# 49    0
# 24    0
# 56    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.07210394, -1.07001372],
#        [ 0.42287984,  0.15595679],
#        [-0.27867197,  1.13172925],
#        [ 1.29981961,  0.15595679],
#        [ 0.86134973,  0.38113505],
#        [ 0.07210394, -0.51957798],
#        [ 0.86134973, -1.49535044],
#        [-0.01559004,  0.00583795],
#        [ 0.24749189, -0.51957798],
#        [-0.5417539 , -0.24436011],
#        [ 1.29981961, -1.57040985],
#        [ 0.77365575, -0.69471663],
#        [ 0.94904371, -1.89566734],
#        [ 0.42287984, -0.84483547],
#        [-0.98022379, -1.57040985],
#        [ 0.07210394,  0.80647176],
#        [-1.41869367,  0.63133312],
#        [-0.71714186, -0.34443934],
#        [-1.76946958, -0.5946374 ],
#        [-0.71714186,  0.20599641],
#        [-0.27867197,  0.40615486],
#        [-1.06791776,  1.13172925],
#        [ 0.77365575,  0.38113505],
#        [ 0.51057382,  0.35611525],
#        [-0.98022379,  1.80726402],
#        [ 0.42287984, -2.17088521],
#        [-1.76946958, -1.22013256],
#        [ 0.33518587,  0.43117467],
#        [ 1.21212564,  0.20599641],
#        [ 0.86134973,  1.88232344],
#        [ 1.38751359,  0.10591718],
#        [ 0.5982678 ,  0.75643215],
#        [-0.5417539 ,  0.38113505],
#        [-0.01559004, -0.54459779],
#        [-0.10328402, -0.44451856],
#        [-0.62944788, -0.24436011],
#        [-0.19097799,  0.45619447],
#        [ 1.12443166, -0.1943205 ],
#        [ 1.82598348,  1.05666983],
#        [-0.27867197,  0.20599641],
#        [ 0.51057382, -0.09424127],
#        [ 1.7382895 , -1.12005334],
#        [ 2.17675938, -0.09424127],
#        [ 1.56290154, -0.24436011],
#        [ 0.68596178,  0.43117467],
#        [ 0.86134973,  1.28184809],
#        [ 0.68596178, -0.29439972],
#        [ 1.12443166, -0.94491469],
#        [-0.98022379, -0.09424127],
#        [-1.06791776,  0.43117467],
#        [ 0.77365575,  0.35611525],
#        [ 0.94904371,  0.68137273],
#        [ 0.24749189,  0.08089737],
#        [-1.50638765,  1.90734325],
#        [ 0.33518587, -0.1943205 ],
#        [-1.85716356, -0.36945914],
#        [ 2.00137143,  1.10670944],
#        [-0.19097799,  1.05666983],
#        [-0.01559004, -1.44531082],
#        [-0.89252981, -0.81981566],
#        [-2.38332742,  1.48200654],
#        [-0.71714186,  2.5078186 ],
#        [ 0.07210394,  0.20599641],
#        [-2.20793946,  2.73299686],
#        [-0.01559004, -1.97072676],
#        [ 1.29981961,  0.85651138],
#        [-1.24330572,  0.5562737 ],
#        [-0.01559004,  0.63133312],
#        [-0.98022379,  0.25603602],
#        [-1.06791776, -0.29439972],
#        [-0.27867197,  0.48121428],
#        [ 1.12443166,  0.33109544],
#        [-0.71714186,  0.9315708 ],
#        [ 0.68596178, -0.84483547],
#        [-1.41869367, -2.04578618],
#        [-0.98022379,  0.78145196],
#        [-0.89252981, -0.14428088],
#        [-1.06791776,  0.98161041],
#        [-0.80483583, -1.44531082],
#        [ 1.12443166, -1.84562773],
#        [-1.15561174, -1.79558811],
#        [-0.80483583,  0.10591718],
#        [-0.5417539 , -0.41949876],
#        [ 0.5982678 ,  1.45698673],
#        [ 0.68596178, -0.01918185],
#        [-0.62944788, -0.06922146],
#        [ 0.24749189,  0.10591718],
#        [ 1.38751359, -0.86985527],
#        [-0.71714186, -0.84483547],
#        [ 0.15979791, -0.26937992]])

# %%
x_test = scaler.fit_transform(x_test)
x_test
# Out:
# array([[-0.69028473, -1.56553179],
#        [ 0.69028473,  1.01267846],
#        [-0.59824677,  1.43795026],
#        [-0.7823227 ,  0.77346308],
#        [ 2.16289216,  0.7203041 ],
#        [ 1.15047455, -0.26313692],
#        [-0.96639863, -0.9276241 ],
#        [-0.32213288,  0.34819128],
#        [-0.96639863, -0.02392154],
#        [ 0.32213288, -1.51237282]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)
y_pred
# Out:
# array([0, 1, 0, 0, 1, 1, 0, 0, 0, 1])

# %%
y_test
# Out:
# 7     0
# 38    1
# 15    0
# 89    0
# 37    1
# 29    1
# 23    0
# 49    0
# 24    0
# 56    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9

# %%
# !pip install mlxtend
from mlxtend.plotting import plot_decision_regions
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.16.3 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from mlxtend) (1.16.3)
# Requirement already satisfied: numpy>=2.3.5 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from mlxtend) (2.3.5)
# Requirement already satisfied: pandas>=2.3.3 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from pandas>=2.3.3->mlxtend) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/harishwargad/Documents/MachineLearning/envs/jupyter/lib/python3.13/site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)
# Downloading mlxtend-0.24.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 658.4 kB/s  0:00:02652.5 kB/s eta 0:00:01
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.24.0

# %%
plot_decision_regions(x_train, y_train.values, clf = clf, legend = 2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf, open('model.pkl', 'wb'))
